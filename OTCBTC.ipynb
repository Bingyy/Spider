# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/Bingyy/Spider/blob/master/OTCBTC.ipynb)

# %%
# !pip install otcbtc_client

# %%
from otcbtc_client.client import OTCBTCClient

# %%
client = OTCBTCClient()

# %%
client.market.all()
# Out:
# [{'id': 'btceth',
#   'minimal_total_volume': 0.0001,
#   'name': 'BTC/ETH',
#   'ticker_id': 'btc_eth',
#   'trading_rule': {'min_amount': 0.001,
#    'min_order_volume': 0.0001,
#    'min_price': 1e-06}},
#  {'id': 'eoseth',
#   'minimal_total_volume': 0.0001,
#   'name': 'EOS/ETH',
#   'ticker_id': 'eos_eth',
#   'trading_rule': {'min_amount': 0.01,
#    'min_order_volume': 0.0001,
#    'min_price': 1e-06}},
#  {'id': 'bcheth',
#   'minimal_total_volume': 0.0001,
#   'name': 'BCH/ETH',
#   'ticker_id': 'bch_eth',
#   'trading_rule': {'min_amount': 0.001,
#    'min_order_volume': 0.0001,
#    'min_price': 1e-05}},
#  {'id': 'gxseth',
#   'minimal_total_volume': 0.0001,
#   'name': 'GXS/ETH',
#   'ticker_id': 'gxs_eth',
#   'trading_rule': {'min_amount': 0.01,
#    'min_order_volume': 0.0001,
#    'min_price': 1e-06}},
#  {'id': 'zeceth',
#   'minimal_total_volume': 0.0001,
#   'name': 'ZEC/ETH',
#   'ticker_id': 'zec_eth',
#   'trading_rule': {'min_amount': 0.001,
# ...

# %%
API_KEY = "OryRluaEBJoLP2uDvVWFS2574P7ONTcCljTYSPnU"
API_SECRET = "DI5xxcxDHvwxajqfhCRcmf4EdAMYa9d2XjTu0wxO"

# %%
auth_client = OTCBTCClient(API_KEY,API_SECRET)

# %%
res = auth_client.market.all()

# %%
res[1]['name']
# Out:
# 'EOS/ETH'

# %% [markdown]
# # 新段落
